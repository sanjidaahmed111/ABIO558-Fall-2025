# %%
# Final Project Description 
# Name: Sanjida Ahmed
# ABIO 558


# Question: 
# Can pentamidine treatment reduce toxic CUG RNA, leading to splicing rescue 
# We can look at RT-PCR data from control and treated cells

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scanpy
import anndata

# %%
## Data Description
     # This data is from the PNS paper 

    # Exons: The two exon splicing events are Clc-1, Serca1 that we are looking at   

    # Condition: Cell treatment conditions are (wildtype), (DM1 + saline), (DM1 + pentamidine doses)

    # Pentamidine Dosage: Categorical variable are none, low and high 

    # Percent Exon Inclusion: % of exon inclusion

    # SEM: Standard error of mean 

    # N: Number of replicates 

## Analysis Plan: 
 
    # Upload the data  

    # Compute descriptive statistics (mean, SD)

    # Visualize exon inclusion across conditions, generating bar plots

    # Test the hypothesis  

    # Maybe do t-tests between control and treatment conditions

    # One-way ANOVA for multiple dosages (if data are normal)

    # For abnormal data, maybe do non-parametric tests as alternatives (Mann–Whitney U or Kruskal–Wallis)

# %%
rt_data = pd.read_csv('rtpcr_splicing_data.csv', header=0, index_col=0)
rt_data
# Out:
#               Condition Pentamidine_Dosage  Percent_Exon_Inclusion  SEM  N
# Gene
# Clc-1                Wt                  -                     6.0  2.0  3
# Clc-1   CUG250 + saline             saline                    55.0  7.0  9
# Clc-1      CUG250 + low                low                    37.0  3.0  5
# Clc-1     CUG250 + high               high                    34.0  5.0  5
# Serca1               Wt                  -                    99.7  0.1  3
# Serca1  CUG250 + saline             saline                    16.0  5.0  9
# Serca1     CUG250 + low                low                    22.0  2.0  5
# Serca1    CUG250 + high               high                    36.0  4.0  5
